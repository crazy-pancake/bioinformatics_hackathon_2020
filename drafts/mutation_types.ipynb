# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

data = pd.read_csv('../data/all_variants_annotated_merged.csv')

# %%
sns.relplot(x='foldx.ddg', y='covar.2d', hue='simplified.significance', col='simplified.significance', data=data);

# %%
sns.relplot(y='foldx.ddg', x='covar.2d', hue='simplified.significance', col='simplified.significance', data=data);

# %%
data.loc[data['simplified.significance'] == 'gnomAD'].shape
# Out:
# (6716, 16)

# %%
data.loc[data['simplified.significance'] == '1/10k'].shape
# Out:
# (358, 16)

# %%
data['simplified.significance'].unique()
# Out:
# array(['pathogenic', 'benign', 'gnomAD', '1/10k', 'common variant'],
#       dtype=object)

# %%
data.loc[data['simplified.significance'] == 'benign']['protein'].unique()
# Out:
# array(['ADSL', 'ASPA', 'BRCA2', 'CBS', 'ELANE', 'F8', 'MEN1', 'MLH1',
#        'MSH2', 'MSH6', 'PMM2', 'GCK', 'RPE65', 'OTC', 'TP53', 'TTR',
#        'VHL'], dtype=object)

# %%
benign = data[data['simplified.significance'] == 'benign']['covar.2d']
sns.distplot(benign)

# %%
benign.isna().sum()
# Out:
# 210

# %%
final = []
w = int(benign.isna().sum() / 7.5)
n = 0.0
for f in [2.5, 1, 1, 1, 1, 1, 1]:
    np.random.uniform(low=n, high=(n + 0.2), size=((w*),))
# Out:
# array([0.16332095, 0.10612051, 0.01441728, 0.16056089, 0.05872   ,
#        0.04451489, 0.0722895 , 0.11207388, 0.08311207, 0.12676946,
#        0.10216097, 0.18396036, 0.11583306, 0.04404934, 0.1668609 ,
#        0.03925331, 0.03282888, 0.04281977, 0.07417515, 0.1559798 ,
#        0.09239424, 0.12976474, 0.06010915, 0.110016  , 0.11706649,
#        0.09638094, 0.01928684, 0.10275193])

# %%
ok = np.random.uniform(low=0.0, high=1, size=(210,))
sns.distplot(ok)
